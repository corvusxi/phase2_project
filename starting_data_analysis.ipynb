# %% [markdown]
# This notebook was used to look at all of the available datasets (and later, the scrapped data) to make decisions on which information to use.

# %%
import sqlite3
import pandas as pd

# %%
#Box Office Mojo
bom_df = pd.read_csv("data/bom.movie_gross.csv")
bom_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
bom_df.sample(10)
# Out:
#                                           title   studio  domestic_gross  \
# 1347                            Stories We Tell    RAtt.       1600000.0
# 1845                               Tasting Menu    Magn.         18700.0
# 2664                              Saala Khadoos      UTV         76900.0
# 1478  The Hobbit: The Battle of the Five Armies  WB (NL)     255100000.0
# 1154        Cloudy with a Chance of Meatballs 2     Sony     119800000.0
# 702                           My Kingdom (2011)       CL         36500.0
# 2087                       Clouds of Sils Maria      IFC       1900000.0
# 2475                                Bad Santa 2       BG      17800000.0
# 1645                                   Wetlands   Strand         59500.0
# 1742                                    Borgman    Drft.         57500.0
#
#      foreign_gross  year
# 1347           NaN  2013
# 1845           NaN  2014
# 2664           NaN  2016
# 1478     700900000  2014
# 1154     154500000  2013
# ...

# %%
bom_df.describe()
# Out:
#        domestic_gross         year
# count    3.359000e+03  3387.000000
# mean     2.874585e+07  2013.958075
# std      6.698250e+07     2.478141
# min      1.000000e+02  2010.000000
# 25%      1.200000e+05  2012.000000
# 50%      1.400000e+06  2014.000000
# 75%      2.790000e+07  2016.000000
# max      9.367000e+08  2018.000000

# %%
#IMDB
conn = sqlite3.connect("data/im.db")

# %%
# %%bash
# sqlite3 data/im.db
# .tables
# Out:
# directors      movie_akas     movie_ratings  principals
# known_for      movie_basics   persons        writers

# %%
# %%bash
# sqlite3 data/im.db
# .schema
# Out:
# CREATE TABLE IF NOT EXISTS "movie_basics" (
# "movie_id" TEXT,
#   "primary_title" TEXT,
#   "original_title" TEXT,
#   "start_year" INTEGER,
#   "runtime_minutes" REAL,
#   "genres" TEXT
# );
# CREATE TABLE IF NOT EXISTS "directors" (
# "movie_id" TEXT,
#   "person_id" TEXT
# );
# CREATE TABLE IF NOT EXISTS "known_for" (
# "person_id" TEXT,
#   "movie_id" TEXT
# );
# CREATE TABLE IF NOT EXISTS "movie_akas" (
# "movie_id" TEXT,
#   "ordering" INTEGER,
#   "title" TEXT,
#   "region" TEXT,
#   "language" TEXT,
#   "types" TEXT,
#   "attributes" TEXT,
#   "is_original_title" REAL
# );
# CREATE TABLE IF NOT EXISTS "movie_ratings" (
# "movie_id" TEXT,
#   "averagerating" REAL,
#   "numvotes" INTEGER
# );
# CREATE TABLE IF NOT EXISTS "persons" (
# "person_id" TEXT,
#   "primary_name" TEXT,
#   "birth_year" REAL,
#   "death_year" REAL,
#   "primary_profession" TEXT
# );
# CREATE TABLE IF NOT EXISTS "principals" (
# "movie_id" TEXT,
#   "ordering" INTEGER,
#   "person_id" TEXT,
# ...

# %%
conn.close()

# %%
#Rotten Tomatoes
rt_info_df = pd.read_csv("data/rt.movie_info.tsv", delimiter = "\t", lineterminator = "\r")
rt_info_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1561 entries, 0 to 1560
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            1561 non-null   object
#  1   synopsis      1498 non-null   object
#  2   rating        1557 non-null   object
#  3   genre         1552 non-null   object
#  4   director      1361 non-null   object
#  5   writer        1111 non-null   object
#  6   theater_date  1201 non-null   object
#  7   dvd_date      1201 non-null   object
#  8   currency      340 non-null    object
#  9   box_office    340 non-null    object
#  10  runtime       1530 non-null   object
#  11  studio        494 non-null    object
# dtypes: object(12)
# memory usage: 146.5+ KB

# %%
rt_info_df.sample(10)
# Out:
#           id                                           synopsis rating  \
# 1536  \n1975  The year is 1953. A visiting archaeologist cal...     NR
# 1309  \n1692  Long before Grease was even thought of, the Br...     PG
# 426    \n559  A pair of hot young southern California surfer...     PG
# 874   \n1132  Driven over the edge by drugs and crime at the...      R
# 400    \n520  From bestselling author, Max Lucado, comes The...     PG
# 314    \n413  Four individuals are called upon by a secret o...     NR
# 1151  \n1483  The Dressmaker tells the story of the beautifu...      R
# 532    \n694  In this suspenseful horror movie, a mother des...      R
# 930   \n1207  Directed by Nicholas Racz, The Burial Society ...      R
# 80     \n100  Four old college friends in their forties come...     NR
#
#                                                   genre  \
# 1536                                      Drama|Romance
# 1309         Classics|Drama|Musical and Performing Arts
# ...

# %%
#Rotten Tomatoes
rt_reviews_df = pd.read_csv("data/rt.reviews.tsv", delimiter = "\t", lineterminator = "\r", encoding="latin-1")
rt_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54433 entries, 0 to 54432
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          54433 non-null  object
#  1   review      48869 non-null  object
#  2   rating      40915 non-null  object
#  3   fresh       54432 non-null  object
#  4   critic      51710 non-null  object
#  5   top_critic  54432 non-null  float64
#  6   publisher   54123 non-null  object
#  7   date        54432 non-null  object
# dtypes: float64(1), object(7)
# memory usage: 3.3+ MB

# %%
rt_reviews_df.sample(10)
# Out:
#            id                                             review rating  \
# 43321  \n1622  The movie is a drama of faith, a Tibetan monk'...    NaN
# 2994     \n95  There's little in Bleed for This that you have...    2/5
# 23834   \n969  While the director may have ambition to admire...    1/5
# 52096  \n1935              A B-movie blast about power and greed    NaN
# 28824  \n1143                                                NaN    1/4
# 53497  \n1968  There's an audience for such lazy sentimentali...    2/5
# 32781  \n1297  Susanna White and Jessica Chastain's Woman Wal...    NaN
# 26949  \n1079                                                NaN    3/5
# 46326  \n1744  Maxwell illuminates the processes of denial an...    NaN
# 34189  \n1329  This anti-feminist parable is both a labor and...    NaN
#
#         fresh                critic  top_critic        publisher  \
# 43321   fresh                   NaN         1.0    Village Voice
# ...

# %%
rt_reviews_df.describe()
# Out:
#          top_critic
# count  54432.000000
# mean       0.240594
# std        0.427448
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
#TheMovieDB
tmdb_df = pd.read_csv("data/tmdb.movies.csv")
tmdb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26517 entries, 0 to 26516
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         26517 non-null  int64
#  1   genre_ids          26517 non-null  object
#  2   id                 26517 non-null  int64
#  3   original_language  26517 non-null  object
#  4   original_title     26517 non-null  object
#  5   popularity         26517 non-null  float64
#  6   release_date       26517 non-null  object
#  7   title              26517 non-null  object
#  8   vote_average       26517 non-null  float64
#  9   vote_count         26517 non-null  int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 2.0+ MB

# %%
tmdb_df.sample(10)
# Out:
#        Unnamed: 0         genre_ids      id original_language  \
# 14672       14672              [18]  339145                en
# 6004         6004          [18, 99]  114562                es
# 9766         9766           [10402]  241678                en
# 24636       24636          [18, 35]  421471                en
# 21823       21823    [10749, 10770]  459828                en
# 25910       25910              [35]  519723                en
# 15701       15701          [28, 27]  457402                en
# 7219         7219                []  157803                en
# 24553       24553  [35, 878, 10749]  396622                en
# 4750         4750       [18, 10751]  329677                xx
#
#                                     original_title  popularity release_date  \
# 14672                         The Girl in the Book       5.959   2015-06-13
# 6004                                      Pelotero       2.255   2012-07-13
# ...

# %%
tmdb_df.describe()
# Out:
#         Unnamed: 0             id    popularity  vote_average    vote_count
# count  26517.00000   26517.000000  26517.000000  26517.000000  26517.000000
# mean   13258.00000  295050.153260      3.130912      5.991281    194.224837
# std     7654.94288  153661.615648      4.355229      1.852946    960.961095
# min        0.00000      27.000000      0.600000      0.000000      1.000000
# 25%     6629.00000  157851.000000      0.600000      5.000000      2.000000
# 50%    13258.00000  309581.000000      1.374000      6.000000      5.000000
# 75%    19887.00000  419542.000000      3.694000      7.000000     28.000000
# max    26516.00000  608444.000000     80.773000     10.000000  22186.000000

# %%
#The Numbers
tn_df = pd.read_csv("data/tn.movie_budgets.csv")
tn_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB

# %%
tn_df.sample(10)
# Out:
#       id  release_date                               movie production_budget  \
# 1428  29  Jul 10, 1998                      Small Soldiers       $40,000,000
# 5296  97  May 15, 2015                           Childless        $1,000,000
# 2664  65  Apr 24, 2015                          Little Boy       $20,000,000
# 4819  20   Jan 1, 1971  Escape from the Planet of the Apes        $2,500,000
# 4734  35   Sep 7, 2012                        Bachelorette        $3,000,000
# 3941  42  Aug 12, 2014                             Swelter        $8,000,000
# 5035  36   Feb 7, 2003                                 May        $1,750,000
# 2280  81   Jul 3, 2002                 The Powerpuff Girls       $25,000,000
# 280   81  Jan 13, 2017                      Monster Trucks      $125,000,000
# 644   45  Nov 11, 2011                           Immortals       $75,000,000
#
#      domestic_gross worldwide_gross
# 1428    $55,143,823     $71,743,823
# 5296         $1,036          $1,036
# ...

# %%
tn_df.describe()
# Out:
#                 id
# count  5782.000000
# mean     50.372363
# std      28.821076
# min       1.000000
# 25%      25.000000
# 50%      50.000000
# 75%      75.000000
# max     100.000000

# %%
#Scrapped: Box Office Mojo
scrapped_bom_df = pd.read_csv("data/bom_scrapy.csv")
scrapped_bom_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title             227 non-null    object
#  1   domestic_revenue  227 non-null    object
#  2   world_revenue     227 non-null    object
#  3   distributor       227 non-null    object
#  4   opening_revenue   225 non-null    object
#  5   opening_theaters  224 non-null    float64
#  6   budget            2 non-null      object
#  7   MPAA              202 non-null    object
#  8   genres            227 non-null    object
#  9   release_days      227 non-null    int64
# dtypes: float64(1), int64(1), object(8)
# memory usage: 17.9+ KB

# %%
scrapped_bom_df.describe()
# Out:
#        opening_theaters  release_days
# count        224.000000    227.000000
# mean        2093.330357    179.140969
# std         1531.437037    130.569879
# min            2.000000     10.000000
# 25%          513.750000     51.000000
# 50%         2294.500000    167.000000
# 75%         3553.000000    293.000000
# max         4600.000000    650.000000
